# %%
import numpy as np
from matplotlib import pyplot as plt
import C_to_O as CO
from T_freeze import T_freeze, Rdes, tevap
from C_to_O import T_freeze_H20, T_freeze_CO2, T_freeze_CO
import matplotlib.cm as cm

from drift_timescales import tr, Tdisk, ts, lambdamfp, cdisk, tdes, rf, r_freeze, read_drag_file, read_drag_file_many, r_stop
from scipy.optimize import brentq
from utils.constants import cmperau

# %%
s, a, arrayH2O = read_drag_file_many('s_neg3_8.txt', 'H2O', 50, 50)
s, a, arrayCO2 = read_drag_file_many('s_neg3_8.txt', 'CO2', 50, 50)
s, a, arrayCO = read_drag_file_many('s_neg3_8.txt', 'CO', 50, 50)

# %%
rfreeze_H2O = r_freeze(18., 5800., 1e6)
rfreeze_CO2 = r_freeze(44., 2000., 3e5)
rfreeze_CO = r_freeze(28., 850., 1e6)

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, sharex = True, figsize = (3.5, 8))

rnb = linspace(0, 256, len(s))

for i in range(len(s)):
    ax1.loglog(a, arrayH2O[i], c = cm.rainbow(int(rnb[i])))
    ax2.loglog(a, arrayCO2[i], c = cm.rainbow(int(rnb[i])))
    ax3.loglog(a, arrayCO[i], c = cm.rainbow(int(rnb[i])))
ax3.set_xlim(xmin = 0.3)
ax3.set_ylim(ymin = 0.3)
ax1.set_ylabel('Desorption distance [AU]')
ax2.set_ylabel('Desorption distance [AU]')
ax3.set_ylabel('Desorption distance [AU]')
ax3.set_xlabel('Initial distance [AU]')

ax1.axhline(y = rfreeze_H2O, ls = '--', c = 'black')
ax2.axhline(y = rfreeze_CO2, ls = '--', c = 'black')
ax3.axhline(y = rfreeze_CO, ls = '--', c = 'black')

ax1.axvline(x = rfreeze_H2O, ls = '--', c = 'black')
ax2.axvline(x = rfreeze_CO2, ls = '--', c = 'black')
ax3.axvline(x = rfreeze_CO, ls = '--', c = 'black')

ax1.text(0.7, 55, 'H2O')
ax2.text(0.7, 55, 'CO2')
ax3.text(0.7, 55, 'CO')

ax1.set_ylim(ymin = 0.3)
ax2.set_ylim(ymin = 0.3)
ax3.set_ylim(ymin = 0.3)

plt.tight_layout()
f.subplots_adjust(hspace = 0)

#plt.savefig('desorption_distace_many.pdf')

# %%
arrayH2O[0]
# Out:
# array([ 0.1       ,  0.11513954,  0.13257114,  0.1526418 ,  0.17575106,
#         0.20235895,  0.23299512,  0.26826928,  0.30888269,  0.35563764,
#         0.40941905,  0.47092078,  0.53811057,  0.59263332,  0.6105508 ,
#         0.61277277,  0.61295808,  0.61296815,  0.61296899,  0.61296957,
#         0.61296998,  0.61296982,  0.61296954,  0.6129693 ,  0.61296968,
#         0.61296942,  0.61296939,  0.61296957,  0.61296945,  0.6129692 ,
#         0.612969  ,  0.61296923,  0.61296907,  0.61296932,  0.61296846,
#         0.61296964,  0.61296921,  0.61296918,  0.61296929,  0.61296874,
#         0.61296894,  0.61296858,  0.61296833,  0.61296757,  0.61296813,
#         0.61296838,  0.612968  ,  0.61296816,  0.61296871,  0.61296858])

# %%
import drift_timescales as dt
reload(dt)

astopH2O, astopCO2, astopCO = [], [], []

for i in range(len(s)):
    astopH2O = append(astopH2O, dt.r_stop(s[i], 18., 5800., rhos = 2.0, mu = 2.3, Sigma0 = 2000, betaS = 1))
    astopCO2 = append(astopCO2, dt.r_stop(s[i], 44., 2000., rhos = 2.0, mu = 2.3, Sigma0 = 2000, betaS = 1))
    astopCO = append(astopCO, dt.r_stop(s[i], 28., 850., rhos = 2.0, mu = 2.3, Sigma0 = 2000, betaS = 1))

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, sharex = True, figsize = (3.5, 8))

rnb = linspace(0, 256, len(s))

ax1.loglog(arrayH2O[:,-1][:27], astopH2O[:27], '.')
ax1.loglog(a, a, '--', c = 'black')
ax2.loglog(arrayCO2[:,-1][:27], astopCO2[:27], '.')
ax2.loglog(a, a, '--', c = 'black')
ax3.loglog(arrayCO[:,-1][:27], astopCO[:27], '.')
ax3.loglog(a, a, '--', c = 'black')
#ax3.set_xlim(xmin = 0.5)
ax3.set_ylim(ymin = 0.1)

ax1.set_ylabel(r'Est. des. $d$ ($t_r = t_{des}$) [cm]')
ax2.set_ylabel(r'Est. des. $d$ ($t_r = t_{des}$) [cm]')
ax3.set_ylabel(r'Est. des. $d$ ($t_r = t_{des}$) [cm]')
ax3.set_xlabel(r'Actual des. $d$ [cm]')

plt.tight_layout()
f.subplots_adjust(hspace = 0)

plt.savefig('desorption_distance_actual_vs_estimated.pdf')

# %%
arrayH2O[:,-1][:27]
# Out:
# array([ 0.61296858,  0.59370781,  0.57479149,  0.55621653,  0.53798215,
#         0.52008675,  0.50252854,  0.48530617,  0.4684181 ,  0.45186283,
#         0.43563884,  0.4197446 ,  0.40417858,  0.38893917,  0.37402435,
#         0.35942845,  0.34511567,  0.33083024,  0.31590353,  0.30382618,
#         0.29767737,  0.29467137,  0.29307677,  0.29218535,  0.29167278,
#         0.29137348,  0.29119713])

# %%
arrayCO2[:,-1][:27]
# Out:
# array([ 8.38885186,  8.14003391,  7.89541334,  7.65496409,  7.41867041,
#         7.18651354,  6.9584751 ,  6.73453859,  6.51468601,  6.29889975,
#         6.08716193,  5.87945417,  5.67575696,  5.47604758,  5.28029562,
#         5.0884511 ,  4.90041525,  4.71597031,  4.53463057,  4.35542267,
#         4.17699565,  3.99914934,  3.8420997 ,  3.75779921,  3.71690804,
#         3.69542255,  3.68347669])

# %%
arrayCO[:,-1][:27]
# Out:
# array([ 66.1406796 ,  64.23705623,  62.36440988,  60.52263288,
#         58.7116727 ,  56.93140844,  55.18172351,  53.46250478,
#         51.77360453,  50.11484764,  48.48596934,  46.88648638,
#         45.31536535,  43.77023701,  42.24580488,  40.73202068,
#         39.21788468,  37.71498862,  36.29115491,  35.04556714,
#         34.02788658,  33.21826029,  32.5693869 ,  32.03786107,
#         31.59187776,  31.20954491,  30.87584277])

# %%
s[27]
# Out:
# 1151.3953993299999

# %%
(1e3 / 1e8)**0.5 * (100. / rfreeze_H2O)**((7 - 3./7)/2)
# Out:
# 44481.85237366611

# %%
(1e3 / 1e8)**0.5 * (100. / rfreeze_CO2)**((7 - 3./7)/2)
# Out:
# 10.110284650968856

# %%
(1e3 / 1e8)**0.5 * (100. / rfreeze_CO)**((7 - 3./7)/2)
# Out:
# 0.01795202086154284
