# %%
import numpy as np
from matplotlib import pyplot as plt
import C_to_O as CO
from T_freeze import T_freeze, Rdes, tevap
from C_to_O import T_freeze_H20, T_freeze_CO2, T_freeze_CO

import matplotlib.cm as cm

from drift_timescales import tr, Tdisk, ts, lambdamfp, cdisk, tdes, rf, r_freeze, \
        read_drag_file, read_drag_file_many, r_stop, Mdot_solids, Mdot_gas, dMgas_dt, dMsol_dt, rdot
from drift_timescales_varying_sigma import dMdot, Mgas_dt, Msol_dt
    
from scipy.optimize import brentq
from utils.constants import cmperau
from matplotlib import animation
from IPython.display import HTML

# %%
r = np.logspace(-1, 2, 500)

# %%
gas_sol_ratio1, gas_sol_ratio2, gas_sol_ratio3 = [], [], []
fH2O = 1e-4

for i in range(len(r) - 1):
    gas_sol_ratio1 = np.append(gas_sol_ratio1, dMgas_dt(r[i], r[i + 1], 0.01, betaS = 1.) / dMsol_dt(r[i], r[i + 1], 1., 44., 5800, betaS = 1.))
    gas_sol_ratio2 = np.append(gas_sol_ratio2, dMgas_dt(r[i], r[i + 1], 0.01, betaS = 1.) / dMsol_dt(r[i], r[i + 1], 1e5, 44., 5800, betaS = 1.))
    gas_sol_ratio3 = np.append(gas_sol_ratio3, dMgas_dt(r[i], r[i + 1], 0.01, betaS = 1.) / dMsol_dt(r[i], r[i + 1], 1e-5, 44., 5800, betaS = 1.))

# %%
gas_sol_ratio1, gas_sol_ratio2, gas_sol_ratio3 = [], [], []
fH2O = 1e-4

for i in range(len(r) - 1):
    gas_sol_ratio1 = np.append(gas_sol_ratio1, (dMgas_dt(r[i], r[i + 1], 0.01, betaS = 1.) + Mgas_dt(r[i], r[i + 1], 1., 44, 5800, betaS = 1.)) \
        / (dMsol_dt(r[i], r[i + 1], 1., 44., 5800, betaS = 1.) + Msol_dt(r[i], r[i + 1], 1., 44, 5800, betaS = 1.)))
    gas_sol_ratio2 = np.append(gas_sol_ratio2, (dMgas_dt(r[i], r[i + 1], 0.01, betaS = 1.) + Mgas_dt(r[i], r[i + 1], 1., 44, 5800, betaS = 1.)) \
        / (dMsol_dt(r[i], r[i + 1], 1., 44., 5800, betaS = 1.) + Msol_dt(r[i], r[i + 1], 1e5, 44, 5800, betaS = 1.)))
    gas_sol_ratio3 = np.append(gas_sol_ratio3, (dMgas_dt(r[i], r[i + 1], 0.01, betaS = 1.) + Mgas_dt(r[i], r[i + 1], 1., 44, 5800, betaS = 1.)) \
        / (dMsol_dt(r[i], r[i + 1], 1., 44., 5800, betaS = 1.) + Msol_dt(r[i], r[i + 1], 1e-5, 44, 5800, betaS = 1.)))

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, sharex = True, figsize = (3.5, 7))

ax1.semilogx(r[:-1], fH2O * gas_sol_ratio1, label = r's=1 cm')
ax2.semilogx(r[:-1], fH2O * gas_sol_ratio2, label = r's=$10^5$ cm')
ax3.semilogx(r[:-1], fH2O * gas_sol_ratio3, label = r's=$10^{-5}$ cm')

ax3.set_xlabel('r [AU]')
ax1.set_ylabel(r'$\Delta M_{H_2O,g}/\Delta M_{H_2O,s}$')
ax2.set_ylabel(r'$\Delta M_{H_2O,g}/\Delta M_{H_2O,s}$')
ax3.set_ylabel(r'$\Delta M_{H_2O,g}/\Delta M_{H_2O,s}$')

ax1.legend(frameon = False)
ax2.legend(frameon = False)
ax3.legend(frameon = False)

plt.tight_layout()
#f.subplots_adjust(hspace = 0)

#plt.savefig('../figs/H2O_gas_to_dust.pdf')

# %%
plt.semilogx(r[:-1], f * gas_sol_ratio1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-fa645f4f2572> in <module>()
# ----> 1 plt.semilogx(r[:-1], f * gas_sol_ratio1)
#
# TypeError: unsupported operand type(s) for *: 'Figure' and 'float'

# %%
f * gas_sol_ratio1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-8154aee51a03> in <module>()
# ----> 1 f * gas_sol_ratio1
#
# TypeError: unsupported operand type(s) for *: 'Figure' and 'float'

# %%
for i in range(len(r)):
    plt.semilogx(r[i], -rdot(r[i], 1., betaS = 1.), '.b')

# %%
for i in range(len(r)):
    plt.loglog(r[i], Mdot_solids(r[i], 1, 44., 5800, betaS = 3./2), '.r')
    plt.semilogx(r[i], Mdot_gas(r[i], 0.01, betaS = 3./2),'.b')

# %%
for i in range(len(r) - 1):
    plt.semilogx(r[i], dMgas_dt(r[i], r[i + 1], 0.01, betaS = 1.), '.b')
    plt.semilogx(r[i], dMsol_dt(r[i], r[i + 1], 1., 44., 5800, betaS = 1.), '.r')

# %%
rdotv = []

for i in range(len(r)):
    rdotv = np.append(rdotv, rdot(r[i], 10, betaS = 1))

# %%
plt.semilogx(r, - rdotv)

# %%
n = 50
m = len(r)

array = np.ndarray(shape = (m - 1, n, 6), dtype = float)

for i in range(m - 1):
    temp = dMdot(r[i], r[i + 1], 0.1, 44., 5800, 1e-6, 3e6 * 365 * 24 * 3600, n, 0.01, betaS=1.)
    for j in range(len(temp[0])):
        array[i, j, 0] = temp[0][j]
        array[i, j, 1] = temp[1][j]
        array[i, j, 2] = temp[2][j]
        array[i, j, 3] = temp[3][j]
        array[i, j, 4] = temp[4][j]
        array[i, j, 5] = temp[5][j]

t = np.linspace(1e-6, 3e6 * 365 * 24 * 3600, n)

# %%
len(array[:,0,0])
# Out:
# 500

# %%
Sigmap = []
for i in range(len(r) - 1):
    Sigmap = np.append(Sigmap, array[i, 30, 4])

# %%
plt.loglog(r[:-1], Sigmap)
plt.loglog(r[:-1], -Sigmap, '--b')

# %%
from tempfile import NamedTemporaryFile

VIDEO_TAG = """<video controls>
 <source src="data:video/x-m4v;base64,{0}" type="video/mp4">
 Your browser does not support the video tag.
</video>"""

def anim_to_html(anim):
    if not hasattr(anim, '_encoded_video'):
        with NamedTemporaryFile(suffix='.mp4') as f:
            anim.save(f.name, fps=20, extra_args=['-vcodec', 'libx264'])
            video = open(f.name, "rb").read()
        anim._encoded_video = video.encode("base64")
    
    return VIDEO_TAG.format(anim._encoded_video)

# %%
def display_animation(anim):
    plt.close(anim._fig)
    return HTML(anim_to_html(anim))

# %%
animation.Animation._repr_html_ = anim_to_html

# %%
fig = plt.figure()
ax = plt.axes()
line, = ax.plot([], [])

def init():
    line.set_data([], [])
    return line,

def animate(i):
    x = r[:-1]
    y = array[:, i, 4]
    line.set_data(x, y)
    return line,

animation.FuncAnimation(fig, animate, init_func = init, frames = 10, interval = 20, blit = True)

#plt.show()
#display_animation(anim)

# %%
plt.plot(animate(0))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-07198de73f81> in <module>()
# ----> 1 plt.plot(animate(0))
#
# /home/apiso/epd_free-7.3-2-rh5-x86_64/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    2456         ax.hold(hold)
#    2457     try:
# -> 2458         ret = ax.plot(*args, **kwargs)
#    2459         draw_if_interactive()
#    2460     finally:
#
# /home/apiso/epd_free-7.3-2-rh5-x86_64/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    3847
#    3848         for line in self._get_lines(*args, **kwargs):
# -> 3849             self.add_line(line)
#    3850             lines.append(line)
#    3851
#
# /home/apiso/epd_free-7.3-2-rh5-x86_64/lib/python2.7/site-packages/matplotlib/axes.pyc in add_line(self, line)
#    1441             line.set_clip_path(self.patch)
#    1442
# -> 1443         self._update_line_limits(line)
#    1444         if not line.get_label():
#    1445             line.set_label('_line%d'%len(self.lines))
#
# /home/apiso/epd_free-7.3-2-rh5-x86_64/lib/python2.7/site-packages/matplotlib/axes.pyc in _update_line_limits(self, line)
#    1449
#    1450     def _update_line_limits(self, line):
# -> 1451         p = line.get_path()
#    1452         if p.vertices.size > 0:
#    1453             self.dataLim.update_from_path(p, self.ignore_existing_data_limits,
#
# /home/apiso/epd_free-7.3-2-rh5-x86_64/lib/python2.7/site-packages/matplotlib/lines.pyc in get_path(self)
#     642         """
#     643         if self._invalidy or self._invalidx:
# --> 644             self.recache()
#     645         return self._path
#     646
#
# /home/apiso/epd_free-7.3-2-rh5-x86_64/lib/python2.7/site-packages/matplotlib/lines.pyc in recache(self, always)
#     399                 y = ma.asarray(yconv, np.float_)
#     400             else:
# --> 401                 y = np.asarray(yconv, np.float_)
#     402             y = y.ravel()
#     403         else:
#
# /home/apiso/epd_free-7.3-2-rh5-x86_64/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     233
#     234     """
# --> 235     return array(a, dtype, copy=False, order=order)
#     236
#     237 def asanyarray(a, dtype=None, order=None):
#
# TypeError: float() argument must be a string or a number
