# %%
from drift_timescales_updated_sigmap_0402_cavity import rf, read_drag_file_many
from utils.constants import Msun

# %%
a = logspace(-1, 2, 50)
s = logspace(-3, 8, 50)

darray = np.ndarray(shape = (len(s), len(a)), dtype = float)

#for i in range(len(s)):
#    for j in range(len(a)):
#        darray[i, j] = rf(a[j], 3e5*365*24*3600, s[i], 18, 5800., 0.01, 1e-3, 0.1*Msun, rhos = 2.0, mu = 2.3)
        #print s[i], a[j]

# %%
a = logspace(-1, 2, 50)
s = logspace(-3, 8, 50)

darrayCO2 = np.ndarray(shape = (len(s), len(a)), dtype = float)

#for i in range(len(s)):
#    for j in range(len(a)):
#        darrayCO2[i, j] = rf(a[j], 3e6*365*24*3600, s[i], 44, 2000., 0.01, 1e-3, 0.1*Msun, rhos = 2.0, mu = 2.3)
#        print s[i], a[j]

# %%
f = open('../dat/H2O/s_neg3_8_varying_sigmap_3e5yr.txt', 'wb')
for i in range(len(s)):
    f.write('%s ' % str(s[i]))
    f.write('%s \n' % str(len(a)))
    for j in range(len(a)):
        f.write(' %s ' % str(a[j]))
        f.write(' %s \n' % str(darray[i, j]))
f.close()

# %%
#a = logspace(-1, 2, 50)
#s = logspace(-3, 8, 50)

#darrayCO = np.ndarray(shape = (len(s), len(a)), dtype = float)

#for i in range(len(s)):
#    for j in range(len(a)):
#        darrayCO[i, j] = rf(a[j], 3e6*365*24*3600, s[i], 28, 850., 0.01, 1e-3, 0.1*Msun, rhos = 2.0, mu = 2.3, Sigma0 = 2e3, betaS = 1)
#        print s[i], a[j]

# %%
s, a, arrayH2O = read_drag_file_many('s_neg3_8_varying_sigmap_3e5yr.txt', 'H2O', 50, 50)

# %%
#f, (ax1, ax2, ax3) = plt.subplots(3, sharex = True, figsize = (3.5, 8))

rnb = linspace(0, 256, len(s))

for i in range(0, len(s)):
    plt.loglog(a, arrayH2O[i], c = cm.rainbow(int(rnb[i])))
plt.ylim(ymin = 0.1, ymax = 1e2)
plt.xlim(xmin = 0.1, xmax = 1e2)
plt.ylabel('Desorption distance [AU]')
plt.xlabel('Initial distance [AU]')
plt.savefig('../figs/desorption_dist_H2O_with_acc_1e5yr.pdf')

# %%
s, a, arrayH2O = read_drag_file_many('s_neg3_8_varying_sigmap.txt', 'CO2', 50, 50)

# %%
a = logspace(-1, 2, 50)
s = 1e2

#darray3e6, darray1e6, darray1e5 = [], [], []
darray3e6, darray1e6, darray1e5, darray1e4 = [], [], [], []

for i in range(len(a)):
    darray3e6 = np.append(darray3e6, rf(a[i], 3e6*365*24*3600, s, 44, 5800., 0.01, 1e-3, 0.1*Msun, rhos = 2.0, mu = 2.3))
    darray1e6 = np.append(darray1e6, rf(a[i], 1e6*365*24*3600, s, 44, 5800., 0.01, 1e-3, 0.1*Msun, rhos = 2.0, mu = 2.3))
    darray1e5 = np.append(darray1e5, rf(a[i], 1e5*365*24*3600, s, 44, 5800., 0.01, 1e-3, 0.1*Msun, rhos = 2.0, mu = 2.3))
    darray1e4 = np.append(darray1e4, rf(a[i], 1e4*365*24*3600, s, 44, 5800., 0.01, 1e-3, 0.1*Msun, rhos = 2.0, mu = 2.3))
    print a[i]
# Out:
# 0.1
# 0.115139539933
# 0.132571136559
# 0.152641796718
# 0.175751062485
# 0.202358964773
# 0.232995181052
# 0.268269579528
# 0.308884359648
# drift_timescales_updated_sigmap_0402_cavity.py:338: RuntimeWarning: invalid value encountered in double_scalars
#   * np.exp(- rtild**(2 - gammad) / T) / 1000
# drift_timescales_updated_sigmap_0402_cavity.py:152: RuntimeWarning: invalid value encountered in double_scalars
#   return ((T0 * r**(-betaT))**4 + 10000.)**0.25
# drift_timescales_updated_sigmap_0402_cavity.py:234: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(G * Mstar / (r * cmperau)**3)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in f(x, t)
#     884
#     885           return np.array([ \
# --> 886                rdot_with_acc(x[0] / cmperau, t, x[1], alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma), \
#     887                - 3 * mx * mp  / rhos * \
#     888                     Nx * Rdes(mx, Ex, Tdisk(x[0] / cmperau, T0, betaT))])
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot_with_acc(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     800     """
#     801
# --> 802     return rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) + \
#     803         vacc_act(r, t, alpha, mu, T0, betaT, rc, Mstar, gammadflag) / \
#     804               (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     751     """
#     752
# --> 753     return - (r * cmperau) / tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     754
#     755
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     705
#     706     return (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)/ \
# --> 707            taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) / \
#     708            (2 * eta(r, t, alpha, dr, Mdisk, rc, T0, betaT, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar))
#     709
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     659     """
#     660
# --> 661     return ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar)
#     662
#     663
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     612                       vrel * CD) - t
#     613
# --> 614         time = brentq(f, 1e-20, 1e30)
#     615
#     616         return time
#
# /Users/ana-mariapiso/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/zeros.pyc in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     388     if type(args) != type(()) :
#     389         args = (args,)
# --> 390     r = _zeros._brentq(f,a,b,xtol,maxiter,args,full_output,disp)
#     391     return results_c(full_output, r)
#     392
#
# RuntimeError: Failed to converge after 100 iterations.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# error: Error occurred while calling the Python function named f
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in f(x, t)
#     884
#     885           return np.array([ \
# --> 886                rdot_with_acc(x[0] / cmperau, t, x[1], alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma), \
#     887                - 3 * mx * mp  / rhos * \
#     888                     Nx * Rdes(mx, Ex, Tdisk(x[0] / cmperau, T0, betaT))])
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot_with_acc(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     800     """
#     801
# --> 802     return rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) + \
#     803         vacc_act(r, t, alpha, mu, T0, betaT, rc, Mstar, gammadflag) / \
#     804               (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     751     """
#     752
# --> 753     return - (r * cmperau) / tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     754
#     755
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     705
#     706     return (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)/ \
# --> 707            taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) / \
#     708            (2 * eta(r, t, alpha, dr, Mdisk, rc, T0, betaT, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar))
#     709
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     659     """
#     660
# --> 661     return ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar)
#     662
#     663
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     612                       vrel * CD) - t
#     613
# --> 614         time = brentq(f, 1e-20, 1e30)
#     615
#     616         return time
#
# /Users/ana-mariapiso/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/zeros.pyc in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     388     if type(args) != type(()) :
#     389         args = (args,)
# --> 390     r = _zeros._brentq(f,a,b,xtol,maxiter,args,full_output,disp)
#     391     return results_c(full_output, r)
#     392
#
# RuntimeError: Failed to converge after 100 iterations.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# error: Error occurred while calling the Python function named f
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in f(x, t)
#     884
#     885           return np.array([ \
# --> 886                rdot_with_acc(x[0] / cmperau, t, x[1], alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma), \
#     887                - 3 * mx * mp  / rhos * \
#     888                     Nx * Rdes(mx, Ex, Tdisk(x[0] / cmperau, T0, betaT))])
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot_with_acc(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     800     """
#     801
# --> 802     return rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) + \
#     803         vacc_act(r, t, alpha, mu, T0, betaT, rc, Mstar, gammadflag) / \
#     804               (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     751     """
#     752
# --> 753     return - (r * cmperau) / tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     754
#     755
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     705
#     706     return (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)/ \
# --> 707            taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) / \
#     708            (2 * eta(r, t, alpha, dr, Mdisk, rc, T0, betaT, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar))
#     709
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     659     """
#     660
# --> 661     return ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar)
#     662
#     663
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     612                       vrel * CD) - t
#     613
# --> 614         time = brentq(f, 1e-20, 1e30)
#     615
#     616         return time
#
# /Users/ana-mariapiso/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/zeros.pyc in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     388     if type(args) != type(()) :
#     389         args = (args,)
# --> 390     r = _zeros._brentq(f,a,b,xtol,maxiter,args,full_output,disp)
#     391     return results_c(full_output, r)
#     392
#
# RuntimeError: Failed to converge after 100 iterations.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# error: Error occurred while calling the Python function named f
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in f(x, t)
#     884
#     885           return np.array([ \
# --> 886                rdot_with_acc(x[0] / cmperau, t, x[1], alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma), \
#     887                - 3 * mx * mp  / rhos * \
#     888                     Nx * Rdes(mx, Ex, Tdisk(x[0] / cmperau, T0, betaT))])
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot_with_acc(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     800     """
#     801
# --> 802     return rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) + \
#     803         vacc_act(r, t, alpha, mu, T0, betaT, rc, Mstar, gammadflag) / \
#     804               (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     751     """
#     752
# --> 753     return - (r * cmperau) / tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     754
#     755
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     705
#     706     return (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)/ \
# --> 707            taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) / \
#     708            (2 * eta(r, t, alpha, dr, Mdisk, rc, T0, betaT, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar))
#     709
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     659     """
#     660
# --> 661     return ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar)
#     662
#     663
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     612                       vrel * CD) - t
#     613
# --> 614         time = brentq(f, 1e-20, 1e30)
#     615
#     616         return time
#
# /Users/ana-mariapiso/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/zeros.pyc in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     388     if type(args) != type(()) :
#     389         args = (args,)
# --> 390     r = _zeros._brentq(f,a,b,xtol,maxiter,args,full_output,disp)
#     391     return results_c(full_output, r)
#     392
#
# RuntimeError: Failed to converge after 100 iterations.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# error: Error occurred while calling the Python function named f
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in f(x, t)
#     884
#     885           return np.array([ \
# --> 886                rdot_with_acc(x[0] / cmperau, t, x[1], alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma), \
#     887                - 3 * mx * mp  / rhos * \
#     888                     Nx * Rdes(mx, Ex, Tdisk(x[0] / cmperau, T0, betaT))])
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot_with_acc(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     800     """
#     801
# --> 802     return rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) + \
#     803         vacc_act(r, t, alpha, mu, T0, betaT, rc, Mstar, gammadflag) / \
#     804               (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     751     """
#     752
# --> 753     return - (r * cmperau) / tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     754
#     755
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     705
#     706     return (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)/ \
# --> 707            taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) / \
#     708            (2 * eta(r, t, alpha, dr, Mdisk, rc, T0, betaT, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar))
#     709
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     659     """
#     660
# --> 661     return ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar)
#     662
#     663
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     612                       vrel * CD) - t
#     613
# --> 614         time = brentq(f, 1e-20, 1e30)
#     615
#     616         return time
#
# /Users/ana-mariapiso/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/zeros.pyc in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     388     if type(args) != type(()) :
#     389         args = (args,)
# --> 390     r = _zeros._brentq(f,a,b,xtol,maxiter,args,full_output,disp)
#     391     return results_c(full_output, r)
#     392
#
# RuntimeError: Failed to converge after 100 iterations.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# error: Error occurred while calling the Python function named f
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in f(x, t)
#     884
#     885           return np.array([ \
# --> 886                rdot_with_acc(x[0] / cmperau, t, x[1], alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma), \
#     887                - 3 * mx * mp  / rhos * \
#     888                     Nx * Rdes(mx, Ex, Tdisk(x[0] / cmperau, T0, betaT))])
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot_with_acc(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     800     """
#     801
# --> 802     return rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) + \
#     803         vacc_act(r, t, alpha, mu, T0, betaT, rc, Mstar, gammadflag) / \
#     804               (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     751     """
#     752
# --> 753     return - (r * cmperau) / tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     754
#     755
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     705
#     706     return (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)/ \
# --> 707            taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) / \
#     708            (2 * eta(r, t, alpha, dr, Mdisk, rc, T0, betaT, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar))
#     709
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     659     """
#     660
# --> 661     return ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar)
#     662
#     663
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     612                       vrel * CD) - t
#     613
# --> 614         time = brentq(f, 1e-20, 1e30)
#     615
#     616         return time
#
# /Users/ana-mariapiso/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/zeros.pyc in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     388     if type(args) != type(()) :
#     389         args = (args,)
# --> 390     r = _zeros._brentq(f,a,b,xtol,maxiter,args,full_output,disp)
#     391     return results_c(full_output, r)
#     392
#
# RuntimeError: Failed to converge after 100 iterations.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# error: Error occurred while calling the Python function named f
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in f(x, t)
#     884
#     885           return np.array([ \
# --> 886                rdot_with_acc(x[0] / cmperau, t, x[1], alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma), \
#     887                - 3 * mx * mp  / rhos * \
#     888                     Nx * Rdes(mx, Ex, Tdisk(x[0] / cmperau, T0, betaT))])
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot_with_acc(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     800     """
#     801
# --> 802     return rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) + \
#     803         vacc_act(r, t, alpha, mu, T0, betaT, rc, Mstar, gammadflag) / \
#     804               (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     751     """
#     752
# --> 753     return - (r * cmperau) / tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     754
#     755
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     705
#     706     return (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)/ \
# --> 707            taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) / \
#     708            (2 * eta(r, t, alpha, dr, Mdisk, rc, T0, betaT, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar))
#     709
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     659     """
#     660
# --> 661     return ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar)
#     662
#     663
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     612                       vrel * CD) - t
#     613
# --> 614         time = brentq(f, 1e-20, 1e30)
#     615
#     616         return time
#
# /Users/ana-mariapiso/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/zeros.pyc in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     388     if type(args) != type(()) :
#     389         args = (args,)
# --> 390     r = _zeros._brentq(f,a,b,xtol,maxiter,args,full_output,disp)
#     391     return results_c(full_output, r)
#     392
#
# RuntimeError: Failed to converge after 100 iterations.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# error: Error occurred while calling the Python function named f
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in f(x, t)
#     884
#     885           return np.array([ \
# --> 886                rdot_with_acc(x[0] / cmperau, t, x[1], alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma), \
#     887                - 3 * mx * mp  / rhos * \
#     888                     Nx * Rdes(mx, Ex, Tdisk(x[0] / cmperau, T0, betaT))])
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot_with_acc(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     800     """
#     801
# --> 802     return rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) + \
#     803         vacc_act(r, t, alpha, mu, T0, betaT, rc, Mstar, gammadflag) / \
#     804               (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     751     """
#     752
# --> 753     return - (r * cmperau) / tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     754
#     755
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     705
#     706     return (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)/ \
# --> 707            taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) / \
#     708            (2 * eta(r, t, alpha, dr, Mdisk, rc, T0, betaT, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar))
#     709
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     659     """
#     660
# --> 661     return ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar)
#     662
#     663
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     612                       vrel * CD) - t
#     613
# --> 614         time = brentq(f, 1e-20, 1e30)
#     615
#     616         return time
#
# /Users/ana-mariapiso/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/zeros.pyc in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     388     if type(args) != type(()) :
#     389         args = (args,)
# --> 390     r = _zeros._brentq(f,a,b,xtol,maxiter,args,full_output,disp)
#     391     return results_c(full_output, r)
#     392
#
# RuntimeError: Failed to converge after 100 iterations.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# error: Error occurred while calling the Python function named f
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 0.355648030622
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in f(x, t)
#     884
#     885           return np.array([ \
# --> 886                rdot_with_acc(x[0] / cmperau, t, x[1], alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma), \
#     887                - 3 * mx * mp  / rhos * \
#     888                     Nx * Rdes(mx, Ex, Tdisk(x[0] / cmperau, T0, betaT))])
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot_with_acc(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     800     """
#     801
# --> 802     return rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) + \
#     803         vacc_act(r, t, alpha, mu, T0, betaT, rc, Mstar, gammadflag) / \
#     804               (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     751     """
#     752
# --> 753     return - (r * cmperau) / tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     754
#     755
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     705
#     706     return (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)/ \
# --> 707            taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) / \
#     708            (2 * eta(r, t, alpha, dr, Mdisk, rc, T0, betaT, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar))
#     709
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     659     """
#     660
# --> 661     return ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar)
#     662
#     663
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     612                       vrel * CD) - t
#     613
# --> 614         time = brentq(f, 1e-20, 1e30)
#     615
#     616         return time
#
# /Users/ana-mariapiso/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/zeros.pyc in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     388     if type(args) != type(()) :
#     389         args = (args,)
# --> 390     r = _zeros._brentq(f,a,b,xtol,maxiter,args,full_output,disp)
#     391     return results_c(full_output, r)
#     392
#
# RuntimeError: Failed to converge after 100 iterations.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# error: Error occurred while calling the Python function named f
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in f(x, t)
#     884
#     885           return np.array([ \
# --> 886                rdot_with_acc(x[0] / cmperau, t, x[1], alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma), \
#     887                - 3 * mx * mp  / rhos * \
#     888                     Nx * Rdes(mx, Ex, Tdisk(x[0] / cmperau, T0, betaT))])
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot_with_acc(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     800     """
#     801
# --> 802     return rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) + \
#     803         vacc_act(r, t, alpha, mu, T0, betaT, rc, Mstar, gammadflag) / \
#     804               (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     751     """
#     752
# --> 753     return - (r * cmperau) / tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     754
#     755
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     705
#     706     return (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)/ \
# --> 707            taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) / \
#     708            (2 * eta(r, t, alpha, dr, Mdisk, rc, T0, betaT, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar))
#     709
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     659     """
#     660
# --> 661     return ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar)
#     662
#     663
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     612                       vrel * CD) - t
#     613
# --> 614         time = brentq(f, 1e-20, 1e30)
#     615
#     616         return time
#
# /Users/ana-mariapiso/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/zeros.pyc in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     388     if type(args) != type(()) :
#     389         args = (args,)
# --> 390     r = _zeros._brentq(f,a,b,xtol,maxiter,args,full_output,disp)
#     391     return results_c(full_output, r)
#     392
#
# RuntimeError: Failed to converge after 100 iterations.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# error: Error occurred while calling the Python function named f
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in f(x, t)
#     884
#     885           return np.array([ \
# --> 886                rdot_with_acc(x[0] / cmperau, t, x[1], alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma), \
#     887                - 3 * mx * mp  / rhos * \
#     888                     Nx * Rdes(mx, Ex, Tdisk(x[0] / cmperau, T0, betaT))])
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot_with_acc(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     800     """
#     801
# --> 802     return rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) + \
#     803         vacc_act(r, t, alpha, mu, T0, betaT, rc, Mstar, gammadflag) / \
#     804               (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     751     """
#     752
# --> 753     return - (r * cmperau) / tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     754
#     755
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     705
#     706     return (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)/ \
# --> 707            taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) / \
#     708            (2 * eta(r, t, alpha, dr, Mdisk, rc, T0, betaT, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar))
#     709
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     659     """
#     660
# --> 661     return ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar)
#     662
#     663
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     612                       vrel * CD) - t
#     613
# --> 614         time = brentq(f, 1e-20, 1e30)
#     615
#     616         return time
#
# /Users/ana-mariapiso/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/zeros.pyc in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     388     if type(args) != type(()) :
#     389         args = (args,)
# --> 390     r = _zeros._brentq(f,a,b,xtol,maxiter,args,full_output,disp)
#     391     return results_c(full_output, r)
#     392
#
# RuntimeError: Failed to converge after 100 iterations.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# error: Error occurred while calling the Python function named f
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in f(x, t)
#     884
#     885           return np.array([ \
# --> 886                rdot_with_acc(x[0] / cmperau, t, x[1], alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma), \
#     887                - 3 * mx * mp  / rhos * \
#     888                     Nx * Rdes(mx, Ex, Tdisk(x[0] / cmperau, T0, betaT))])
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot_with_acc(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     800     """
#     801
# --> 802     return rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) + \
#     803         vacc_act(r, t, alpha, mu, T0, betaT, rc, Mstar, gammadflag) / \
#     804               (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     751     """
#     752
# --> 753     return - (r * cmperau) / tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     754
#     755
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     705
#     706     return (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)/ \
# --> 707            taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) / \
#     708            (2 * eta(r, t, alpha, dr, Mdisk, rc, T0, betaT, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar))
#     709
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     659     """
#     660
# --> 661     return ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar)
#     662
#     663
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     612                       vrel * CD) - t
#     613
# --> 614         time = brentq(f, 1e-20, 1e30)
#     615
#     616         return time
#
# /Users/ana-mariapiso/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/zeros.pyc in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     388     if type(args) != type(()) :
#     389         args = (args,)
# --> 390     r = _zeros._brentq(f,a,b,xtol,maxiter,args,full_output,disp)
#     391     return results_c(full_output, r)
#     392
#
# RuntimeError: Failed to converge after 100 iterations.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# error: Error occurred while calling the Python function named f
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in f(x, t)
#     884
#     885           return np.array([ \
# --> 886                rdot_with_acc(x[0] / cmperau, t, x[1], alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma), \
#     887                - 3 * mx * mp  / rhos * \
#     888                     Nx * Rdes(mx, Ex, Tdisk(x[0] / cmperau, T0, betaT))])
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot_with_acc(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     800     """
#     801
# --> 802     return rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) + \
#     803         vacc_act(r, t, alpha, mu, T0, betaT, rc, Mstar, gammadflag) / \
#     804               (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     751     """
#     752
# --> 753     return - (r * cmperau) / tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     754
#     755
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     705
#     706     return (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)/ \
# --> 707            taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) / \
#     708            (2 * eta(r, t, alpha, dr, Mdisk, rc, T0, betaT, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar))
#     709
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     659     """
#     660
# --> 661     return ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar)
#     662
#     663
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     612                       vrel * CD) - t
#     613
# --> 614         time = brentq(f, 1e-20, 1e30)
#     615
#     616         return time
#
# /Users/ana-mariapiso/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/zeros.pyc in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     388     if type(args) != type(()) :
#     389         args = (args,)
# --> 390     r = _zeros._brentq(f,a,b,xtol,maxiter,args,full_output,disp)
#     391     return results_c(full_output, r)
#     392
#
# RuntimeError: Failed to converge after 100 iterations.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# error: Error occurred while calling the Python function named f
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in f(x, t)
#     884
#     885           return np.array([ \
# --> 886                rdot_with_acc(x[0] / cmperau, t, x[1], alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma), \
#     887                - 3 * mx * mp  / rhos * \
#     888                     Nx * Rdes(mx, Ex, Tdisk(x[0] / cmperau, T0, betaT))])
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot_with_acc(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     800     """
#     801
# --> 802     return rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) + \
#     803         vacc_act(r, t, alpha, mu, T0, betaT, rc, Mstar, gammadflag) / \
#     804               (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     751     """
#     752
# --> 753     return - (r * cmperau) / tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     754
#     755
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     705
#     706     return (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)/ \
# --> 707            taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) / \
#     708            (2 * eta(r, t, alpha, dr, Mdisk, rc, T0, betaT, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar))
#     709
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     659     """
#     660
# --> 661     return ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar)
#     662
#     663
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     612                       vrel * CD) - t
#     613
# --> 614         time = brentq(f, 1e-20, 1e30)
#     615
#     616         return time
#
# /Users/ana-mariapiso/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/zeros.pyc in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     388     if type(args) != type(()) :
#     389         args = (args,)
# --> 390     r = _zeros._brentq(f,a,b,xtol,maxiter,args,full_output,disp)
#     391     return results_c(full_output, r)
#     392
#
# RuntimeError: Failed to converge after 100 iterations.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# error: Error occurred while calling the Python function named f
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in f(x, t)
#     884
#     885           return np.array([ \
# --> 886                rdot_with_acc(x[0] / cmperau, t, x[1], alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma), \
#     887                - 3 * mx * mp  / rhos * \
#     888                     Nx * Rdes(mx, Ex, Tdisk(x[0] / cmperau, T0, betaT))])
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot_with_acc(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     800     """
#     801
# --> 802     return rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) + \
#     803         vacc_act(r, t, alpha, mu, T0, betaT, rc, Mstar, gammadflag) / \
#     804               (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     751     """
#     752
# --> 753     return - (r * cmperau) / tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     754
#     755
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     705
#     706     return (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)/ \
# --> 707            taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) / \
#     708            (2 * eta(r, t, alpha, dr, Mdisk, rc, T0, betaT, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar))
#     709
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     659     """
#     660
# --> 661     return ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar)
#     662
#     663
#
# ...
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in f(x, t)
#     884
#     885           return np.array([ \
# --> 886                rdot_with_acc(x[0] / cmperau, t, x[1], alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma), \
#     887                - 3 * mx * mp  / rhos * \
#     888                     Nx * Rdes(mx, Ex, Tdisk(x[0] / cmperau, T0, betaT))])
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot_with_acc(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     800     """
#     801
# --> 802     return rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) + \
#     803         vacc_act(r, t, alpha, mu, T0, betaT, rc, Mstar, gammadflag) / \
#     804               (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     751     """
#     752
# --> 753     return - (r * cmperau) / tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     754
#     755
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     705
#     706     return (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)/ \
# --> 707            taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) / \
#     708            (2 * eta(r, t, alpha, dr, Mdisk, rc, T0, betaT, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar))
#     709
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     659     """
#     660
# --> 661     return ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar)
#     662
#     663
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     612                       vrel * CD) - t
#     613
# --> 614         time = brentq(f, 1e-20, 1e30)
#     615
#     616         return time
#
# /Users/ana-mariapiso/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/zeros.pyc in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     388     if type(args) != type(()) :
#     389         args = (args,)
# --> 390     r = _zeros._brentq(f,a,b,xtol,maxiter,args,full_output,disp)
#     391     return results_c(full_output, r)
#     392
#
# RuntimeError: Failed to converge after 100 iterations.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# error: Error occurred while calling the Python function named f
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in f(x, t)
#     884
#     885           return np.array([ \
# --> 886                rdot_with_acc(x[0] / cmperau, t, x[1], alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma), \
#     887                - 3 * mx * mp  / rhos * \
#     888                     Nx * Rdes(mx, Ex, Tdisk(x[0] / cmperau, T0, betaT))])
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot_with_acc(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     800     """
#     801
# --> 802     return rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) + \
#     803         vacc_act(r, t, alpha, mu, T0, betaT, rc, Mstar, gammadflag) / \
#     804               (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in rdot(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     751     """
#     752
# --> 753     return - (r * cmperau) / tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     754
#     755
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in tr(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     705
#     706     return (1 + taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)**2)/ \
# --> 707            taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) / \
#     708            (2 * eta(r, t, alpha, dr, Mdisk, rc, T0, betaT, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar))
#     709
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in taus(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     659     """
#     660
# --> 661     return ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma) * Omegak(r, Mstar)
#     662
#     663
#
# /Users/ana-mariapiso/Thesis/python/drift_timescales_updated_sigmap_0402_cavity.py in ts(r, t, s, alpha, dr, Mdisk, rc, T0, betaT, rhos, mu, Mstar, gammadflag, sigma)
#     612                       vrel * CD) - t
#     613
# --> 614         time = brentq(f, 1e-20, 1e30)
#     615
#     616         return time
#
# /Users/ana-mariapiso/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scipy/optimize/zeros.pyc in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     388     if type(args) != type(()) :
#     389         args = (args,)
# --> 390     r = _zeros._brentq(f,a,b,xtol,maxiter,args,full_output,disp)
#     391     return results_c(full_output, r)
#     392
#
# RuntimeError: Failed to converge after 100 iterations.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# error: Error occurred while calling the Python function named f
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 3.90693993705
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 4.49843266897
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 5.17947467923
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 5.96362331659
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 6.86648845004
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 7.90604321091
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 9.10298177992
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 10.4811313415
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 12.0679264064
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 13.8949549437
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 15.9985871961
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 18.4206996933
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 21.2095088792
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 24.4205309455
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 28.1176869797
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 32.3745754282
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 37.2759372031
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 42.9193426013
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 49.4171336132
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 56.8986602902
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 65.512855686
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 75.4312006335
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 86.8511373751
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# Excess work done on this call (perhaps wrong Dfun type).
# Run with full_output = 1 to get quantitative information.
# 100.0

# %%
f = open('../dat/H2O/act_cavity_1000_s_100cm_3e6.txt', 'wb')
for i in range(len(a)):
    f.write(' %s ' % str(a[i]))
    f.write(' %s \n' % str(darray3e6[i]))
f.close()

# %%
ai3e6, af3e6 = [], []

f = open('../dat/H2O/act_s_100cm_3e6.txt', 'r')
for line in f:
    ai3e6 = np.append(ai3e6, float(line.split()[0]))
    af3e6 = np.append(af3e6, float(line.split()[1]))
f.close()  

ai1e6, af1e6 = [], []

f = open('../dat/H2O/act_s_100cm_1e6.txt', 'r')
for line in f:
    ai1e6 = np.append(ai1e6, float(line.split()[0]))
    af1e6 = np.append(af1e6, float(line.split()[1]))
f.close() 

ai1e5, af1e5 = [], []

f = open('../dat/H2O/act_s_100cm_1e5.txt', 'r')
for line in f:
    ai1e5 = np.append(ai1e5, float(line.split()[0]))
    af1e5 = np.append(af1e5, float(line.split()[1]))
f.close()

ai1e4, af1e4 = [], []

f = open('../dat/H2O/act_s_100cm_1e4.txt', 'r')
for line in f:
    ai1e4 = np.append(ai1e4, float(line.split()[0]))
    af1e4 = np.append(af1e4, float(line.split()[1]))
f.close() 



ai3e6CO2, af3e6CO2 = [], []

f = open('../dat/CO2/act_s_100cm_3e6.txt', 'r')
for line in f:
    ai3e6CO2 = np.append(ai3e6CO2, float(line.split()[0]))
    af3e6CO2 = np.append(af3e6CO2, float(line.split()[1]))
f.close()  

ai1e6CO2, af1e6CO2 = [], []

f = open('../dat/CO2/act_s_100cm_1e6.txt', 'r')
for line in f:
    ai1e6CO2 = np.append(ai1e6CO2, float(line.split()[0]))
    af1e6CO2 = np.append(af1e6CO2, float(line.split()[1]))
f.close() 

ai1e5CO2, af1e5CO2 = [], []

f = open('../dat/CO2/act_s_100cm_1e5.txt', 'r')
for line in f:
    ai1e5CO2 = np.append(ai1e5CO2, float(line.split()[0]))
    af1e5CO2 = np.append(af1e5CO2, float(line.split()[1]))
f.close()

ai1e4CO2, af1e4CO2 = [], []

f = open('../dat/CO2/act_s_100cm_1e4.txt', 'r')
for line in f:
    ai1e4CO2 = np.append(ai1e4CO2, float(line.split()[0]))
    af1e4CO2 = np.append(af1e4CO2, float(line.split()[1]))
f.close() 




ai3e6CO, af3e6CO = [], []

f = open('../dat/CO/act_s_100cm_3e6.txt', 'r')
for line in f:
    ai3e6CO = np.append(ai3e6CO, float(line.split()[0]))
    af3e6CO = np.append(af3e6CO, float(line.split()[1]))
f.close()  

ai1e6CO, af1e6CO = [], []

f = open('../dat/CO/act_s_100cm_1e6.txt', 'r')
for line in f:
    ai1e6CO = np.append(ai1e6CO, float(line.split()[0]))
    af1e6CO = np.append(af1e6CO, float(line.split()[1]))
f.close() 

ai1e5CO, af1e5CO = [], []

f = open('../dat/CO/act_s_100cm_1e5.txt', 'r')
for line in f:
    ai1e5CO = np.append(ai1e5CO, float(line.split()[0]))
    af1e5CO = np.append(af1e5CO, float(line.split()[1]))
f.close()

ai1e4CO, af1e4CO = [], []

f = open('../dat/CO/act_s_100cm_1e4.txt', 'r')
for line in f:
    ai1e4CO = np.append(ai1e4CO, float(line.split()[0]))
    af1e4CO = np.append(af1e4CO, float(line.split()[1]))
f.close()

# %%
ai3e610, af3e610 = [], []

f = open('../dat/H2O/act_s_10cm_3e6.txt', 'r')
for line in f:
    ai3e610 = np.append(ai3e610, float(line.split()[0]))
    af3e610 = np.append(af3e610, float(line.split()[1]))
f.close()  

ai1e610, af1e610 = [], []

f = open('../dat/H2O/act_s_10cm_1e6.txt', 'r')
for line in f:
    ai1e610 = np.append(ai1e610, float(line.split()[0]))
    af1e610 = np.append(af1e610, float(line.split()[1]))
f.close() 

ai1e510, af1e510 = [], []

f = open('../dat/H2O/act_s_10cm_1e5.txt', 'r')
for line in f:
    ai1e510 = np.append(ai1e510, float(line.split()[0]))
    af1e510 = np.append(af1e510, float(line.split()[1]))
f.close()

ai1e410, af1e410 = [], []

f = open('../dat/H2O/act_s_10cm_1e4.txt', 'r')
for line in f:
    ai1e410 = np.append(ai1e410, float(line.split()[0]))
    af1e410 = np.append(af1e410, float(line.split()[1]))
f.close() 




ai3e6CO210, af3e6CO210 = [], []

f = open('../dat/CO2/act_s_10cm_3e6.txt', 'r')
for line in f:
    ai3e6CO210 = np.append(ai3e6CO210, float(line.split()[0]))
    af3e6CO210 = np.append(af3e6CO210, float(line.split()[1]))
f.close()  

ai1e6CO210, af1e6CO210 = [], []

f = open('../dat/CO2/act_s_10cm_1e6.txt', 'r')
for line in f:
    ai1e6CO210 = np.append(ai1e6CO210, float(line.split()[0]))
    af1e6CO210 = np.append(af1e6CO210, float(line.split()[1]))
f.close() 

ai1e5CO210, af1e5CO210 = [], []

f = open('../dat/CO2/act_s_10cm_1e5.txt', 'r')
for line in f:
    ai1e5CO210 = np.append(ai1e5CO210, float(line.split()[0]))
    af1e5CO210 = np.append(af1e5CO210, float(line.split()[1]))
f.close()

ai1e4CO210, af1e4CO210 = [], []

f = open('../dat/CO2/act_s_10cm_1e4.txt', 'r')
for line in f:
    ai1e4CO210 = np.append(ai1e4CO210, float(line.split()[0]))
    af1e4CO210 = np.append(af1e4CO210, float(line.split()[1]))
f.close() 




ai3e6CO10, af3e6CO10 = [], []

f = open('../dat/CO/act_s_10cm_3e6.txt', 'r')
for line in f:
    ai3e6CO10 = np.append(ai3e6CO10, float(line.split()[0]))
    af3e6CO10 = np.append(af3e6CO10, float(line.split()[1]))
f.close()  

ai1e6CO10, af1e6CO10 = [], []

f = open('../dat/CO/act_s_10cm_1e6.txt', 'r')
for line in f:
    ai1e6CO10 = np.append(ai1e6CO10, float(line.split()[0]))
    af1e6CO10 = np.append(af1e6CO10, float(line.split()[1]))
f.close() 

ai1e5CO10, af1e5CO10 = [], []

f = open('../dat/CO/act_s_10cm_1e5.txt', 'r')
for line in f:
    ai1e5CO10 = np.append(ai1e5CO10, float(line.split()[0]))
    af1e5CO10 = np.append(af1e5CO10, float(line.split()[1]))
f.close()

ai1e4CO10, af1e4CO10 = [], []

f = open('../dat/CO/act_s_10cm_1e4.txt', 'r')
for line in f:
    ai1e4CO10 = np.append(ai1e4CO10, float(line.split()[0]))
    af1e4CO10 = np.append(af1e4CO10, float(line.split()[1]))
f.close()

# %%
fig, ((ax1, ax110), (ax2, ax210), (ax3, ax310)) = plt.subplots(3, 2, sharex = True, sharey = True)

ax1.loglog(ai3e6, af3e6, label = '3 Myr')
ax1.loglog(ai1e6, af1e6, label = '1 Myr')
ax1.loglog(ai1e5, af1e5, label = r'$10^5$ yr')
ax1.loglog(ai1e4, af1e4, label = r'$10^4$ yr')
ax1.legend(loc = 2, frameon = False, prop = {'size':7.5})
#ax1.set_ylabel('Final Distance [AU]')

ax2.loglog(ai3e6CO2, af3e6CO2, label = '3 Myr')
ax2.loglog(ai1e6CO2, af1e6CO2, label = '1 Myr')
ax2.loglog(ai1e5CO2, af1e5CO2, label = r'$10^5$ yr')
ax2.loglog(ai1e4CO2, af1e4CO2, label = r'$10^4$ yr')
#ax2.set_ylim(1e-1, 98)


ax3.loglog(ai3e6CO, af3e6CO, label = '3 Myr')
ax3.loglog(ai1e6CO, af1e6CO, label = '1 Myr')
ax3.loglog(ai1e5CO, af1e5CO, label = r'$10^5$ yr')
ax3.loglog(ai1e4CO, af1e4CO, label = r'$10^4$ yr')
#ax3.set_xlabel('Initial Distance [AU]')


ax110.loglog(ai3e610, af3e610, label = '3 Myr')
ax110.loglog(ai1e610, af1e610, label = '1 Myr')
ax110.loglog(ai1e510, af1e510, label = r'$10^5$ yr')
ax110.loglog(ai1e410, af1e410, label = r'$10^4$ yr')

ax210.loglog(ai3e6CO210, af3e6CO210, label = '3 Myr')
ax210.loglog(ai1e6CO210, af1e6CO210, label = '1 Myr')
ax210.loglog(ai1e5CO210, af1e5CO210, label = r'$10^5$ yr')
ax210.loglog(ai1e4CO210, af1e4CO210, label = r'$10^4$ yr')

ax310.loglog(ai3e6CO10, af3e6CO10, label = '3 Myr')
ax310.loglog(ai1e6CO10, af1e6CO10, label = '1 Myr')
ax310.loglog(ai1e5CO10, af1e5CO10, label = r'$10^5$ yr')
ax310.loglog(ai1e4CO10, af1e4CO10, label = r'$10^4$ yr')

ax2.set_yticks([1e-1, 1e0, 1e1])
ax2.yaxis.set_ticklabels([r"$10^{-1}$", r"$10^0$", r"$10^1$"])

ax1.set_xticks([1e0, 1e1, 1e2])
ax1.xaxis.set_ticklabels([r"$10^0$", r"$10^1$", r"$10^2$"])

ax1.set_title('1 m')
ax110.set_title('10 cm')

ax1.text(4, 25, r'H$_2$O')
ax2.text(4, 25, r'CO$_2$')
ax3.text(4, 25, r'CO')

ax110.text(4, 25, r'H$_2$O')
ax210.text(4, 25, r'CO$_2$')
ax310.text(4, 25, r'CO')

ax1 = fig.add_axes( [0., 0., 1, 1] )
ax1.set_axis_off()
#ax1.set_xlim(0, 1)
#ax.set_ylim(0, 1)
ax1.text( 
    .05, 0.5, "Desorption / final distance [AU]", rotation='vertical',
    horizontalalignment='center', verticalalignment='center')
ax1.text(0.5, .02, 'Initial distance [AU]', horizontalalignment= 'center')

#plt.tight_layout()
fig.subplots_adjust(hspace = 0, wspace = 0)
plt.savefig('../figs/time_plots.pdf')

# %%
ai3e6Md, af3e6Md = [], []

f = open('../dat/H2O/act_cavity_1000_s_100cm_3e6.txt', 'r')
for line in f:
    ai3e6Md = np.append(ai3e6Md, float(line.split()[0]))
    af3e6Md = np.append(af3e6Md, float(line.split()[1]))
f.close()  

ai1e6Md, af1e6Md = [], []

f = open('../dat/H2O/act_cavity_1000_s_100cm_1e6.txt', 'r')
for line in f:
    ai1e6Md = np.append(ai1e6Md, float(line.split()[0]))
    af1e6Md = np.append(af1e6Md, float(line.split()[1]))
f.close() 

ai1e5Md, af1e5Md = [], []

f = open('../dat/H2O/act_cavity_1000_s_100cm_1e5.txt', 'r')
for line in f:
    ai1e5Md = np.append(ai1e5Md, float(line.split()[0]))
    af1e5Md = np.append(af1e5Md, float(line.split()[1]))
f.close()

ai1e4Md, af1e4Md = [], []

f = open('../dat/H2O/act_cavity_1000_s_100cm_1e4.txt', 'r')
for line in f:
    ai1e4Md = np.append(ai1e4Md, float(line.split()[0]))
    af1e4Md = np.append(af1e4Md, float(line.split()[1]))
f.close()

# %%
plt.figure(figsize = (4,0.75*4))

#plt.loglog(ai3e6, af3e6, label = '3 Myr')
#plt.loglog(ai1e6, af1e6, label = '1 Myr')
#plt.loglog(ai1e5, af1e5, label = r'$10^5$ yr')
#p1, = plt.loglog(ai1e4, af1e4, label = r'$10^4$ yr')

plt.loglog(ai3e6Md, af3e6Md, '.b')
#plt.loglog(ai1e6Md, af1e6Md, 'g')
#plt.loglog(ai1e5Md, af1e5Md, 'r')
#p2, = plt.loglog(ai1e4Md, af1e4Md, 'c')

#l1 = legend([p1, p2], ['Full disk', 'Transition disk'], frameon = False, loc = 4, \
            #borderpad = -0.1)

plt.legend(loc = 2, frameon = False, labelspacing = 0)
#gca().add_artist(l1)
plt.title('s=1 m')
plt.xlabel('Initial distance [AU]')
plt.ylabel('Desorption / final distance [AU]')

plt.tight_layout()

#plt.savefig('../figs/desorption_distance_transition_disk_1000.pdf')

# %%
a
# Out:
# array([   0.1       ,    0.11513954,    0.13257114,    0.1526418 ,
#           0.17575106,    0.20235896,    0.23299518,    0.26826958,
#           0.30888436,    0.35564803,    0.40949151,    0.47148664,
#           0.54286754,    0.62505519,    0.71968567,    0.82864277,
#           0.95409548,    1.09854114,    1.26485522,    1.45634848,
#           1.67683294,    1.93069773,    2.22299648,    2.55954792,
#           2.9470517 ,    3.39322177,    3.90693994,    4.49843267,
#           5.17947468,    5.96362332,    6.86648845,    7.90604321,
#           9.10298178,   10.48113134,   12.06792641,   13.89495494,
#          15.9985872 ,   18.42069969,   21.20950888,   24.42053095,
#          28.11768698,   32.37457543,   37.2759372 ,   42.9193426 ,
#          49.41713361,   56.89866029,   65.51285569,   75.43120063,
#          86.85113738,  100.        ])
