# %%
from drift_timescales_updated_sigmap import rf, read_drag_file_many
from utils.constants import Msun

# %%
a = logspace(-1, 2, 50)
s = logspace(-3, 8, 50)

darray = np.ndarray(shape = (len(s), len(a)), dtype = float)

#for i in range(len(s)):
#    for j in range(len(a)):
#        darray[i, j] = rf(a[j], 3e5*365*24*3600, s[i], 18, 5800., 0.01, 1e-3, 0.1*Msun, rhos = 2.0, mu = 2.3)
        #print s[i], a[j]

# %%
a = logspace(-1, 2, 50)
s = logspace(-3, 8, 50)

darrayCO2 = np.ndarray(shape = (len(s), len(a)), dtype = float)

#for i in range(len(s)):
#    for j in range(len(a)):
#        darrayCO2[i, j] = rf(a[j], 3e6*365*24*3600, s[i], 44, 2000., 0.01, 1e-3, 0.1*Msun, rhos = 2.0, mu = 2.3)
#        print s[i], a[j]

# %%
f = open('../dat/H2O/s_neg3_8_varying_sigmap_3e5yr.txt', 'wb')
for i in range(len(s)):
    f.write('%s ' % str(s[i]))
    f.write('%s \n' % str(len(a)))
    for j in range(len(a)):
        f.write(' %s ' % str(a[j]))
        f.write(' %s \n' % str(darray[i, j]))
f.close()

# %%
#a = logspace(-1, 2, 50)
#s = logspace(-3, 8, 50)

#darrayCO = np.ndarray(shape = (len(s), len(a)), dtype = float)

#for i in range(len(s)):
#    for j in range(len(a)):
#        darrayCO[i, j] = rf(a[j], 3e6*365*24*3600, s[i], 28, 850., 0.01, 1e-3, 0.1*Msun, rhos = 2.0, mu = 2.3, Sigma0 = 2e3, betaS = 1)
#        print s[i], a[j]

# %%
s, a, arrayH2O = read_drag_file_many('s_neg3_8_varying_sigmap_3e5yr.txt', 'H2O', 50, 50)

# %%
#f, (ax1, ax2, ax3) = plt.subplots(3, sharex = True, figsize = (3.5, 8))

rnb = linspace(0, 256, len(s))

for i in range(0, len(s)):
    plt.loglog(a, arrayH2O[i], c = cm.rainbow(int(rnb[i])))
plt.ylim(ymin = 0.1, ymax = 1e2)
plt.xlim(xmin = 0.1, xmax = 1e2)
plt.ylabel('Desorption distance [AU]')
plt.xlabel('Initial distance [AU]')
#plt.savefig('../figs/desorption_dist_H2O_with_acc.pdf')

# %%
s, a, arrayH2O = read_drag_file_many('s_neg3_8_varying_sigmap.txt', 'CO2', 50, 50)

# %%
a = logspace(-1, 2, 50)
s = 1e2

#darray3e6, darray1e6, darray1e5 = [], [], []
darray1e4 = []

for i in range(len(a)):
    #darray3e6 = np.append(darray3e6, rf(a[i], 3e6*365*24*3600, s, 18, 5800., 0.01, 1e-3, 0.1*Msun, rhos = 2.0, mu = 2.3))
    #darray1e6 = np.append(darray1e6, rf(a[i], 1e6*365*24*3600, s, 18, 5800., 0.01, 1e-3, 0.1*Msun, rhos = 2.0, mu = 2.3))
    #darray1e5 = np.append(darray1e5, rf(a[i], 1e5*365*24*3600, s, 18, 5800., 0.01, 1e-3, 0.1*Msun, rhos = 2.0, mu = 2.3))
    darray1e4 = np.append(darray1e4, rf(a[i], 1e4*365*24*3600, s, 18, 5800., 0.01, 1e-3, 0.1*Msun, rhos = 2.0, mu = 2.3))
    print a[i]
# Out:
# 0.1
# 0.115139539933
# 0.132571136559
# 0.152641796718
# 0.175751062485
# 0.202358964773
# 0.232995181052
# 0.268269579528
# 0.308884359648
# 0.355648030622
# 0.409491506238
# 0.471486636346
# 0.542867543932
# 0.625055192527
# 0.719685673001
# 0.828642772855
# 0.95409547635
# 1.09854114199
# 1.26485521686
# 1.4563484775
# 1.67683293681
# 1.93069772888
# 2.22299648253
# 2.5595479227
# 2.94705170255
# 3.3932217719
# 3.90693993705
# 4.49843266897
# 5.17947467923
# 5.96362331659
# 6.86648845004
# 7.90604321091
# 9.10298177992
# 10.4811313415
# 12.0679264064
# 13.8949549437
# 15.9985871961
# 18.4206996933
# 21.2095088792
# 24.4205309455
# 28.1176869797
# 32.3745754282
# 37.2759372031
# 42.9193426013
# 49.4171336132
# 56.8986602902
# 65.512855686
# 75.4312006335
# 86.8511373751
# 100.0

# %%
f = open('../dat/H2O/act_s_100cm_1e5.txt', 'wb')
for i in range(len(a)):
    f.write(' %s ' % str(a[i]))
    f.write(' %s \n' % str(darray1e5[i]))
f.close()

# %%
ai, af = [], []

f = open('../dat/H2O/act_s_100cm_3e6.txt', 'r')
for line in f:
    ai = np.append(ai, float(line.split()[0]))
    af = np.append(af, float(line.split()[1]))
f.close()

# %%
plt.loglog(ai, af)
plt.loglog(a, darray1e6)
plt.loglog(a, darray1e5)
plt.loglog(a, darray1e4)

# %%
darray1e5
# Out:
# array([  0.09999921,   0.11513688,   0.13256151,   0.15260425,
#          0.17559319,   0.20164572,   0.22964679,   0.25405194,
#          0.26642546,   0.26954629,   0.27005644,   0.2701249 ,
#          0.27013293,   0.27013377,   0.27013384,   0.27013386,
#          0.27013387,   0.27013388,   0.27013389,   0.2701339 ,
#          0.2701339 ,   0.27013391,   0.27013391,   0.27013392,
#          0.27013393,   0.27013394,   0.27013393,   0.27013394,
#          0.27013395,   0.27013395,   0.27013396,   0.27013397,
#          0.27013398,   0.27013399,   0.270134  ,   0.27013402,
#          0.27013405,   0.27013408,   0.27013413,   0.27013419,
#          0.27013427,   0.27013438,   0.27013453,   0.27013474,
#          0.27013502,   0.2701354 ,   0.27013593,   0.27013667,
#         35.12174961,  66.30864926])
