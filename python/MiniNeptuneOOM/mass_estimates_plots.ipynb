# %%
import os
os.chdir('/home/apiso/repos/Thesis/python')

from utils.constants import G, AU, Me, Re, Msun, kb, Rfn
import numpy as np
from scipy.optimize import brentq
from MiniNeptuneOOM.mass_estimates import mtrans, mthermal, MBondi, MHill, Matm

# %%
a = np.linspace(0.01, 1, 50)

#b = 0 
b = 1./2
d = 3./2
#FT = 1000./300 
FT = 1.
FSigma = 20.
mstar = 1.

MH, mth, mtr = [], [], []
for i in range(len(a)):
    MH = append(MH, MHill(a[i], b, d, FT, FSigma, mstar))
    mth = append(mth, mthermal(a[i], b, FT, mstar))
    mtr = append(mtr, mtrans(a[i], b, FT, mstar))

# %%
mth
# Out:
# array([  1.49980520e+27,   7.87287414e+27,   1.69740769e+28,
#          2.81419951e+28,   4.10469367e+28,   5.54803363e+28,
#          7.12946916e+28,   8.83784933e+28,   1.06643583e+29,
#          1.26017981e+29,   1.46441462e+29,   1.67862671e+29,
#          1.90237130e+29,   2.13525832e+29,   2.37694201e+29,
#          2.62711313e+29,   2.88549292e+29,   3.15182842e+29,
#          3.42588872e+29,   3.70746192e+29,   3.99635266e+29,
#          4.29238008e+29,   4.59537610e+29,   4.90518398e+29,
#          5.22165711e+29,   5.54465797e+29,   5.87405720e+29,
#          6.20973285e+29,   6.55156969e+29,   6.89945859e+29,
#          7.25329607e+29,   7.61298373e+29,   7.97842794e+29,
#          8.34953940e+29,   8.72623285e+29,   9.10842677e+29,
#          9.49604312e+29,   9.88900706e+29,   1.02872468e+30,
#          1.06906933e+30,   1.10992803e+30,   1.15129439e+30,
#          1.19316225e+30,   1.23552567e+30,   1.27837893e+30,
#          1.32171649e+30,   1.36553299e+30,   1.40982326e+30,
#          1.45458229e+30,   1.49980520e+30])

# %%
plot(a, MH)
#plot(a, mth / Me)
plot(a, mtr / Me)

# %%
#Mcore = array([34.6, 13.7, 6.7, 8.8, 3.1]) 
Mcore = linspace(2, 20, 13)

Matmarray = 0 * np.ndarray(shape = (len(Mcore), len(a)), dtype = float)

for i in range(len(Mcore)):
    for j in range(len(a)):
        Matmarray[i, j] = Matm(Mcore[i], a[j], b, d, FT, FSigma, mstar, maxQ = 1)

# %%
Mcore
# Out:
# array([  2. ,   3.5,   5. ,   6.5,   8. ,   9.5,  11. ,  12.5,  14. ,
#         15.5,  17. ,  18.5,  20. ])

# %%
Matmarray[-1]
# Out:
# array([ 0.08623163,  0.11367973,  0.12920872,  0.14056805,  0.14969511,
#         0.15740456,  0.16412334,  0.17010559,  0.17551595,  0.18046773,
#         0.1850425 ,  0.18930111,  0.19329028,  0.19704672,  0.20059984,
#         0.20397359,  0.20718778,  0.21025899,  0.21320122,  0.21602645,
#         0.21874499,  0.22136579,  0.22389668,  0.22634454,  0.22871547,
#         0.23101487,  0.23324759,  0.23541798,  0.23752995,  0.23958703,
#         0.24159246,  0.24354915,  0.24545979,  0.24732683,  0.24915251,
#         0.25093893,  0.25268798,  0.25440145,  0.25608099,  0.25772811,
#         0.25934424,  0.26093072,  0.26248877,  0.26401956,  0.26552418,
#         0.26700365,  0.26845892,  0.26989091,  0.27130046,  0.27268837])

# %%
Matmarray[0]
# Out:
# array([ 0.10577878,  0.02015116,  0.00934646,  0.0056374 ,  0.00386503,
#         0.00285953,  0.00222524,  0.00179509,  0.00148764,  0.00125893,
#         0.00108335,  0.0009451 ,  0.00083395,  0.00074299,  0.00066744,
#         0.00060389,  0.00054981,  0.00050335,  0.00046308,  0.00042791,
#         0.00039698,  0.0003696 ,  0.00034523,  0.00032343,  0.00030383,
#         0.00028613,  0.00027008,  0.00025548,  0.00024215,  0.00022994,
#         0.00021872,  0.00020839,  0.00019885,  0.00019001,  0.00018181,
#         0.00017418,  0.00016707,  0.00016043,  0.00015422,  0.0001484 ,
#         0.00014293,  0.0001378 ,  0.00013296,  0.0001284 ,  0.0001241 ,
#         0.00012003,  0.00011618,  0.00011253,  0.00010907,  0.00010578])

# %%
for i in range(len(Mcore)):
    plot(a, Matmarray[i])

# %%
#loglog(a, MH, '--')
for i in range(len(Mcore)):
    plot(a, Matmarray[i])
#plot(a, mth / Me)
#plot(a, mtr / Me, ':')  A

# %%
for i in range(len(Mcore)):
    plot(a, Matmarray[i])

# %%
envnow = array([0.3, 4.6, 8.2, 17.2, 4.1])/100
env10 = array([87.6, 6.0, 16.5, 21.2, 29])/100
env100 = array([90.4, 9.1, 28, 28.1, 35])/100

Mcorenow = array([4.3, 13.5, 6.1, 8.4, 2.3])
Mcore10 = array([44.8, 14.2, 7.8, 9.7, 3.4])
Mcore100 = array([34.6, 13.7, 6.7, 8.8, 3.1]) #linspace(2, 50, 13)

a = [0.091, 0.106, 0.159, 0.194, 0.25]

Matmarraynow = 0 * np.ndarray(shape = (len(Mcorenow)), dtype = float)
Matmarray10 = 0 * np.ndarray(shape = (len(Mcorenow)), dtype = float)
Matmarray100 = 0 * np.ndarray(shape = (len(Mcorenow)), dtype = float)

a = [0.091, 0.106, 0.159, 0.194, 0.25]

for i in range(len(Mcore)):
    #or j in range(len(a)):
    Matmarraynow[i] = Matm(Mcorenow[i], a[i], b, d, FT, FSigma, mstar, maxQ = 1)
    Matmarray10[i] = Matm(Mcore10[i], a[i], b, d, FT, FSigma, mstar, maxQ = 1)
    Matmarray100[i] = Matm(Mcore100[i], a[i], b, d, FT, FSigma, mstar, maxQ = 1)

# %%
for i in range(len(Mcorenow)):
    plot(a[i], Matmarraynow[i], 'ob')
    plot(a[i], envnow[i], 'bs')
    plot(a[i], Matmarray10[i], 'or')
    plot(a[i], env10[i], 'rs')
    plot(a[i], Matmarray100[i], 'og')
    plot(a[i], env100[i], 'gs')

# %%
Matmarraynow
# Out:
# array([ 0.53192304,  0.53192304,  0.53192304,  0.53192304,  0.07715037])

# %%
for i in range(len(Mcore)):
    plot(a, Matmarray[i], 'o')
plot([0.091, 0.106, 0.159, 0.194, 0.25], array([0.3, 4.6, 8.2, 17.2, 4.1])/100, 'o')
plot([0.091, 0.106, 0.159, 0.194, 0.25], array([87.6, 6.0, 16.5, 21.2, 29])/100, 'o')
plot([0.091, 0.106, 0.159, 0.194, 0.25], array([90.4, 9.1, 28, 28.1, 35])/100, 'o')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-a3632f930068> in <module>()
#       1 for i in range(len(Mcore)):
# ----> 2     plot(a, Matmarray[i], 'o')
#       3 plot([0.091, 0.106, 0.159, 0.194, 0.25], array([0.3, 4.6, 8.2, 17.2, 4.1])/100, 'o')
#       4 plot([0.091, 0.106, 0.159, 0.194, 0.25], array([87.6, 6.0, 16.5, 21.2, 29])/100, 'o')
#       5 plot([0.091, 0.106, 0.159, 0.194, 0.25], array([90.4, 9.1, 28, 28.1, 35])/100, 'o')
#
# /home/apiso/epd_free-7.3-2-rh5-x86_64/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    2456         ax.hold(hold)
#    2457     try:
# -> 2458         ret = ax.plot(*args, **kwargs)
#    2459         draw_if_interactive()
#    2460     finally:
#
# /home/apiso/epd_free-7.3-2-rh5-x86_64/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    3846         lines = []
#    3847
# -> 3848         for line in self._get_lines(*args, **kwargs):
#    3849             self.add_line(line)
#    3850             lines.append(line)
#
# /home/apiso/epd_free-7.3-2-rh5-x86_64/lib/python2.7/site-packages/matplotlib/axes.pyc in _grab_next_args(self, *args, **kwargs)
#     321                 return
#     322             if len(remaining) <= 3:
# --> 323                 for seg in self._plot_args(remaining, kwargs):
#     324                     yield seg
#     325                 return
#
# /home/apiso/epd_free-7.3-2-rh5-x86_64/lib/python2.7/site-packages/matplotlib/axes.pyc in _plot_args(self, tup, kwargs)
#     298             x = np.arange(y.shape[0], dtype=float)
#     299
# --> 300         x, y = self._xy_from_xy(x, y)
#     301
#     302         if self.command == 'plot':
#
# /home/apiso/epd_free-7.3-2-rh5-x86_64/lib/python2.7/site-packages/matplotlib/axes.pyc in _xy_from_xy(self, x, y)
#     238         y = np.atleast_1d(y)
#     239         if x.shape[0] != y.shape[0]:
# --> 240             raise ValueError("x and y must have same first dimension")
#     241         if x.ndim > 2 or y.ndim > 2:
#     242             raise ValueError("x and y can be no greater than 2-D")
#
# ValueError: x and y must have same first dimension

# %%
plot(a, Matmarray[0])
plot(a, Matmarray[1])
#plot(a, Matmarray[-1])

# %%
4./(3*np.sqrt(2*np.pi))
# Out:
# 0.53192304053524364
